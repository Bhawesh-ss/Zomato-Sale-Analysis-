# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("D:\Goklyn\Zomato Project\Zomato-data-.csv")
print(df.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.0    775
# 1         Spice Elephant          Yes         No   4.0    787
# 2        San Churro Cafe          Yes         No   3.0    918
# 3  Addhuri Udupi Bhojana           No         No   3.0     88
# 4          Grand Village           No         No   3.0    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
print(dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB
# None

# %%
def handleRate(value):
    value = str(value).strip("/")
    value = value[0]
    return float(value)

dataframe['rate'] = dataframe['rate'].apply(handleRate)

# %%
print(df.rate)
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      3.0
# 4      3.0
#       ...
# 143    3.0
# 144    3.0
# 145    4.0
# 146    3.0
# 147    3.0
# Name: rate, Length: 148, dtype: float64

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("Type Of Restaurant")
# Out:
# Text(0.5, 0, 'Type Of Restaurant')

# %%
group_data = dataframe.groupby('listed_in(type)')['votes'].sum()
print(group_data)
# Out:
# listed_in(type)
# Buffet     3028
# Cafes      6434
# Dining    20363
# other      9367
# Name: votes, dtype: int64

# %%
result = pd.DataFrame({'votes':group_data})
plt.plot(result,color='blue',marker='D')

plt.xlabel('Type of Restaurant',color='green', size= 20)
plt.ylabel('Number Of Votes',color='red', size= 20)
# Out:
# Text(0, 0.5, 'Number Of Votes')

# %%
max_votes = dataframe['votes'].max()
restaurant_with_max_votes = dataframe.loc[dataframe['votes'] == max_votes,'name'].values

print("Restaurant's with The Maximum Votes:",restaurant_with_max_votes)
# Out:
# Restaurant's with The Maximum Votes: ['Empire Restaurant']

# %%
min_votes = dataframe['votes'].min()
restaurant_with_min_votes = dataframe.loc[dataframe['votes'] == min_votes,'name']

print("Restaurant's with The Minimum Votes:",restaurant_with_min_votes)
# Out:
# Restaurant's with The Minimum Votes: 72                         Spicy Tandoor
# 75                 Om Sri Vinayaka Chats
# 84                             Chill Out
# 90                        Me And My Cake
# 91                               Sunsadm
# 92                Annapooraneshwari Mess
# 107                        Coffee Shopee
# 110                  Hari Super Sandwich
# 113     Dharwad Line Bazaar Mishra Pedha
# 114                            Cake Bite
# 115                  Aarush's Food Plaza
# 116                           Wood Stove
# 117                         Kulfi & More
# 118                  Kannadigas Karavali
# 125                 Soms Kitchen & Bakes
# 126              Banashankari Nati Style
# 128                    Mohitesh Hut Roll
# 129    Sri Basaveshwar Jolada Rotti Oota
# 130                 Roll Magic Fast Food
# 131            Foodlieious Multi Cuisine
# 132    Thanishka Nati And Karavali Style
# 133                    Swathi Cool Point
# ...

# %%
print(dataframe.loc[72])
# Out:
# name                           Spicy Tandoor
# online_order                              No
# book_table                                No
# rate                                   4.1/5
# votes                                      0
# approx_cost(for two people)              150
# listed_in(type)                       Dining
# Name: 72, dtype: object

# %%
sns.countplot(x=dataframe['online_order'],palette=['green','red'])
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=dataframe['book_table'], palette = ['green','blue'])
plt.xlabel("Booking Availability", fontsize=14, fontweight="bold", color="darkorange")
plt.ylabel("Number of Restaurants", fontsize=14, fontweight="bold", color="darkred")
plt.title("Booking Table Status", fontsize=18, fontweight="bold", color="purple")
# Out:
# Text(0.5, 1.0, 'Booking Table Status')

# %%
couple_data=dataframe['approx_cost(for two people)']
plt.figure(figsize=(10, 5))
sns.countplot(x=couple_data , width=0.7,palette='magma')
plt.xlabel("Approximate Cost (For Two People)",size=15)
plt.ylabel("Count of Restaurants",size=15)
plt.title("Cost Distribution",size=20,color='darkblue')
sns.despine()
